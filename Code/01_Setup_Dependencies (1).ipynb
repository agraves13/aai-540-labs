# %% [markdown]
# # Setup All Workshop Dependencies
#
# ## _Note:  This Notebook Will Take A Few Minutes To Complete._
#
# ## _Please Be Patient._

# %%
# !python --version
# Out:
# Python 3.10.13

# %%
# !pip list
# Out:
# Package                               Version
# ------------------------------------- ----------------
# absl-py                               2.0.0
# accelerate                            0.21.0
# aiobotocore                           2.7.0
# aiohttp                               3.8.6
# aioitertools                          0.11.0
# aiosignal                             1.3.1
# aiosqlite                             0.19.0
# altair                                5.1.2
# amazon-codewhisperer-jupyterlab-ext   2.0.1
# amazon-sagemaker-jupyter-scheduler    3.0.4
# ansi2html                             0.0.0
# ansiwrap                              0.8.4
# antlr4-python3-runtime                4.9.3
# anyio                                 3.7.1
# appdirs                               1.4.4
# archspec                              0.2.2
# argon2-cffi                           23.1.0
# argon2-cffi-bindings                  21.2.0
# arrow                                 1.3.0
# astroid                               3.0.1
# asttokens                             2.4.1
# astunparse                            1.6.3
# async-lru                             2.0.4
# async-timeout                         4.0.3
# attrs                                 23.1.0
# autogluon                             0.8.2
# autogluon.common                      0.8.2
# autogluon.core                        0.8.2
# autogluon.features                    0.8.2
# autogluon.multimodal                  0.8.2
# autogluon.tabular                     0.8.2
# autogluon.timeseries                  0.8.2
# autopep8                              2.0.4
# autovizwidget                         0.21.0
# aws-embedded-metrics                  3.2.0
# aws-glue-sessions                     1.0.2
# Babel                                 2.13.1
# backports.functools-lru-cache         1.6.5
# beautifulsoup4                        4.12.2
# binaryornot                           0.4.4
# black                                 23.10.1
# bleach                                6.1.0
# blinker                               1.7.0
# blis                                  0.7.10
# boltons                               23.0.0
# boto3                                 1.28.64
# botocore                              1.31.64
# Brotli                                1.0.9
# cached-property                       1.5.2
# cachetools                            5.3.2
# catalogue                             2.0.10
# catboost                              1.2.2
# certifi                               2023.7.22
# cffi                                  1.16.0
# chardet                               5.2.0
# charset-normalizer                    3.3.2
# click                                 8.1.7
# cloudpathlib                          0.16.0
# cloudpickle                           2.2.1
# colorama                              0.4.6
# comm                                  0.1.4
# conda                                 23.10.0
# conda-libmamba-solver                 23.11.0
# conda-package-handling                2.2.0
# conda_package_streaming               0.9.0
# confection                            0.1.3
# contextlib2                           21.6.0
# contourpy                             1.2.0
# cookiecutter                          2.4.0
# croniter                              1.4.1
# cryptography                          41.0.5
# cycler                                0.12.1
# cymem                                 2.0.8
# cytoolz                               0.12.2
# dash                                  2.14.1
# dask                                  2023.10.1
# dataclasses                           0.8
# dataclasses-json                      0.5.7
# datasets                              2.14.6
# debugpy                               1.8.0
# decorator                             5.1.1
# deepmerge                             1.1.0
# defusedxml                            0.7.1
# dill                                  0.3.7
# distributed                           2023.10.1
# docker-pycreds                        0.4.0
# docstring-to-markdown                 0.13
# entrypoints                           0.4
# et-xmlfile                            1.1.0
# evaluate                              0.4.1
# exceptiongroup                        1.1.3
# executing                             2.0.1
# faiss                                 1.7.4
# fastai                                2.7.13
# fastcore                              1.5.29
# fastdownload                          0.0.7
# fastjsonschema                        2.18.1
# fastprogress                          1.0.3
# filelock                              3.13.1
# flake8                                6.1.0
# Flask                                 3.0.0
# flatbuffers                           23.5.26
# fonttools                             4.44.0
# fqdn                                  1.5.1
# frozenlist                            1.4.0
# fsspec                                2023.6.0
# future                                0.18.3
# gast                                  0.4.0
# gdown                                 4.7.1
# gitdb                                 4.0.11
# GitPython                             3.1.40
# gluonts                               0.13.7
# gmpy2                                 2.1.2
# google-api-core                       2.13.0
# google-auth                           2.23.4
# google-auth-oauthlib                  1.0.0
# google-pasta                          0.2.0
# googleapis-common-protos              1.61.0
# graphviz                              0.20.1
# greenlet                              3.0.1
# grpcio                                1.54.3
# gssapi                                1.8.3
# h5py                                  3.10.0
# hdijupyterutils                       0.21.0
# huggingface-hub                       0.19.0
# idna                                  3.4
# imagecodecs                           2023.8.12
# imageio                               2.31.5
# importlib-metadata                    6.8.0
# importlib-resources                   6.1.1
# ipykernel                             6.26.0
# ipython                               8.17.2
# ipywidgets                            8.1.1
# isoduration                           20.11.0
# isort                                 5.12.0
# itsdangerous                          2.1.2
# jax                                   0.4.19
# jaxlib                                0.4.14
# jedi                                  0.19.1
# Jinja2                                3.1.2
# jmespath                              1.0.1
# joblib                                1.3.2
# json5                                 0.9.14
# jsonpatch                             1.33
# jsonpath-ng                           1.6.0
# jsonpointer                           2.4
# jsonschema                            4.17.3
# jupyter                               1.0.0
# jupyter_ai                            2.5.0
# jupyter_ai_magics                     2.5.0
# jupyter_client                        8.6.0
# jupyter-console                       6.6.3
# jupyter_core                          5.5.0
# jupyter-dash                          0.4.2
# jupyter-events                        0.6.3
# jupyter-lsp                           2.2.0
# jupyter_scheduler                     2.3.0
# jupyter_server                        2.10.0
# jupyter_server_proxy                  4.1.0
# jupyter_server_terminals              0.4.4
# jupyterlab                            4.0.8
# jupyterlab-pygments                   0.2.2
# jupyterlab_server                     2.24.0
# jupyterlab-widgets                    3.0.9
# keras                                 2.12.0
# Keras-Preprocessing                   1.1.2
# kiwisolver                            1.4.5
# krb5                                  0.5.1
# langchain                             0.0.318
# langcodes                             3.3.0
# langsmith                             0.0.60
# libmambapy                            1.5.3
# lightgbm                              3.3.5
# lightning-utilities                   0.9.0
# llvmlite                              0.41.1
# locket                                1.0.0
# Markdown                              3.5.1
# markdown-it-py                        3.0.0
# MarkupSafe                            2.1.3
# marshmallow                           3.20.1
# marshmallow-enum                      1.5.1
# matplotlib                            3.8.1
# matplotlib-inline                     0.1.6
# mccabe                                0.7.0
# mdurl                                 0.1.0
# mistune                               3.0.2
# ml-dtypes                             0.3.1
# mlforecast                            0.7.3
# mock                                  5.1.0
# model-index                           0.1.11
# mpmath                                1.3.0
# msgpack                               1.0.6
# multidict                             6.0.4
# multiprocess                          0.70.15
# munkres                               1.1.4
# murmurhash                            1.0.10
# mypy-extensions                       1.0.0
# nbclient                              0.8.0
# nbconvert                             7.11.0
# nbformat                              5.9.2
# nest-asyncio                          1.5.8
# networkx                              3.2.1
# nlpaug                                1.1.11
# nltk                                  3.8.1
# nose                                  1.3.7
# notebook                              7.0.6
# notebook_shim                         0.2.3
# nptyping                              2.4.1
# numba                                 0.58.1
# numexpr                               2.8.7
# numpy                                 1.26.0
# oauthlib                              3.2.2
# omegaconf                             2.2.3
# openai                                0.28.1
# openapi-schema-pydantic               1.2.4
# openmim                               0.3.7
# openpyxl                              3.1.2
# opt-einsum                            3.3.0
# ordered-set                           4.1.0
# overrides                             7.4.0
# packaging                             23.2
# pandas                                2.1.2
# pandas-stubs                          2.1.1.230928
# pandocfilters                         1.5.0
# papermill                             2.4.0
# parso                                 0.8.3
# partd                                 1.4.1
# pathos                                0.3.1
# pathspec                              0.11.2
# pathtools                             0.1.2
# pathy                                 0.10.2
# patsy                                 0.5.3
# pexpect                               4.8.0
# pickleshare                           0.7.5
# Pillow                                9.5.0
# pip                                   23.3.1
# pkgutil_resolve_name                  1.3.10
# platformdirs                          3.5.1
# plotly                                5.18.0
# pluggy                                1.3.0
# ply                                   3.11
# pox                                   0.3.3
# ppft                                  1.7.6.7
# preshed                               3.0.9
# prometheus-client                     0.18.0
# prompt-toolkit                        3.0.39
# protobuf                              4.21.12
# psutil                                5.9.5
# ptyprocess                            0.7.0
# pure-eval                             0.2.2
# pure-sasl                             0.6.2
# pyarrow                               12.0.1
# pyasn1                                0.5.0
# pyasn1-modules                        0.3.0
# pycodestyle                           2.11.1
# pycosat                               0.6.6
# pycparser                             2.21
# pydantic                              1.10.13
# pydocstyle                            6.3.0
# pyflakes                              3.1.0
# Pygments                              2.16.1
# PyHive                                0.7.0
# PyJWT                                 2.8.0
# pylint                                3.0.2
# pyOpenSSL                             23.3.0
# pyparsing                             3.1.1
# PyQt5                                 5.15.9
# PyQt5-sip                             12.12.2
# pyrsistent                            0.20.0
# PySocks                               1.7.1
# pyspnego                              0.9.1
# pytesseract                           0.3.10
# python-dateutil                       2.8.2
# python-json-logger                    2.0.7
# python-lsp-jsonrpc                    1.1.2
# python-lsp-server                     1.9.0
# python-slugify                        8.0.1
# pytoolconfig                          1.2.5
# pytorch-lightning                     2.0.9
# pytorch-metric-learning               1.7.3
# pytz                                  2023.3
# pyu2f                                 0.1.5
# PyWavelets                            1.4.1
# PyYAML                                6.0.1
# pyzmq                                 25.1.1
# qtconsole                             5.5.0
# QtPy                                  2.4.1
# regex                                 2023.10.3
# requests                              2.31.0
# requests-kerberos                     0.14.0
# requests-oauthlib                     1.3.1
# responses                             0.18.0
# retrying                              1.3.3
# rfc3339-validator                     0.1.4
# rfc3986-validator                     0.1.1
# rich                                  13.6.0
# rope                                  1.11.0
# rsa                                   4.9
# ruamel.yaml                           0.18.5
# ruamel.yaml.clib                      0.2.7
# s3transfer                            0.7.0
# sacremoses                            0.0.53
# safetensors                           0.3.3
# sagemaker                             2.197.0
# sagemaker-headless-execution-driver   0.0.9
# sagemaker-jupyterlab-emr-extension    0.1.9
# sagemaker-jupyterlab-extension        0.1.9
# sagemaker-jupyterlab-extension-common 0.1.9
# sagemaker-kernel-wrapper              0.0.2
# sagemaker-studio-analytics-extension  0.0.21
# sagemaker-studio-sparkmagic-lib       0.1.4
# sasl                                  0.3.1
# schema                                0.7.5
# scikit-image                          0.19.3
# scikit-learn                          1.3.2
# scipy                                 1.11.3
# Send2Trash                            1.8.2
# sentencepiece                         0.1.99
# sentry-sdk                            1.34.0
# seqeval                               1.2.2
# setproctitle                          1.3.3
# setuptools                            68.2.2
# shellingham                           1.5.4
# simpervisor                           1.0.0
# sip                                   6.7.12
# six                                   1.16.0
# smart-open                            5.2.1
# smdebug-rulesconfig                   1.0.1
# smmap                                 5.0.0
# sniffio                               1.3.0
# snowballstemmer                       2.2.0
# sortedcontainers                      2.4.0
# soupsieve                             2.5
# spacy                                 3.7.2
# spacy-legacy                          3.0.12
# spacy-loggers                         1.0.5
# sparkmagic                            0.21.0
# SQLAlchemy                            1.4.49
# srsly                                 2.4.8
# stack-data                            0.6.2
# statsforecast                         1.4.0
# statsmodels                           0.14.0
# stringcase                            1.2.0
# supervisor                            4.2.5
# sympy                                 1.12
# tabulate                              0.9.0
# tblib                                 1.7.0
# tenacity                              8.2.3
# tensorboard                           2.12.3
# tensorboard-data-server               0.7.0
# tensorflow                            2.12.1
# tensorflow-estimator                  2.12.0
# termcolor                             2.3.0
# terminado                             0.17.1
# text-unidecode                        1.3
# textwrap3                             0.9.2
# thinc                                 8.2.1
# threadpoolctl                         3.2.0
# thrift                                0.19.0
# thrift-sasl                           0.4.3
# tifffile                              2023.9.26
# tiktoken                              0.5.1
# timm                                  0.9.10
# tinycss2                              1.2.1
# tokenizers                            0.13.3
# toml                                  0.10.2
# tomli                                 2.0.1
# tomlkit                               0.12.2
# toolz                                 0.12.0
# torch                                 2.0.0.post101
# torchmetrics                          1.0.3
# torchvision                           0.15.2a0+072ec57
# tornado                               6.3.3
# tqdm                                  4.66.1
# traitlets                             5.13.0
# transformers                          4.31.0
# truststore                            0.8.0
# typer                                 0.9.0
# types-python-dateutil                 2.8.19.14
# types-pytz                            2023.3.1.1
# typing_extensions                     4.5.0
# typing-inspect                        0.9.0
# typing-utils                          0.1.0
# typish                                1.9.3
# tzdata                                2023.3
# ujson                                 5.8.0
# unicodedata2                          15.1.0
# uri-template                          1.3.0
# urllib3                               1.26.18
# wandb                                 0.15.12
# wasabi                                1.1.2
# wcwidth                               0.2.9
# weasel                                0.3.4
# webcolors                             1.13
# webencodings                          0.5.1
# websocket-client                      1.6.4
# Werkzeug                              3.0.1
# whatthepatch                          1.0.5
# wheel                                 0.41.3
# widgetsnbextension                    4.0.9
# window-ops                            0.0.14
# wrapt                                 1.15.0
# xgboost                               1.7.6
# xxhash                                3.4.1
# yapf                                  0.40.1
# yarl                                  1.9.2
# zict                                  3.0.0
# zipp                                  3.17.0
# zstandard                             0.22.0

# %% [markdown]
# # Pip

# %%
# !pip install --disable-pip-version-check -q pip --upgrade > /dev/null
# !pip install --disable-pip-version-check -q wrapt --upgrade > /dev/null
# Out:
# WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ConnectTimeoutError(<pip._vendor.urllib3.connection.HTTPSConnection object at 0x7fbec1a257b0>, 'Connection to pypi.org timed out. (connect timeout=15)')': /simple/pip/
# WARNING: Retrying (Retry(total=3, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ConnectTimeoutError(<pip._vendor.urllib3.connection.HTTPSConnection object at 0x7fbec1a25930>, 'Connection to pypi.org timed out. (connect timeout=15)')': /simple/pip/
# WARNING: Retrying (Retry(total=2, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ConnectTimeoutError(<pip._vendor.urllib3.connection.HTTPSConnection object at 0x7fbec1a25ea0>, 'Connection to pypi.org timed out. (connect timeout=15)')': /simple/pip/
# WARNING: Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ConnectTimeoutError(<pip._vendor.urllib3.connection.HTTPSConnection object at 0x7fbec1a26020>, 'Connection to pypi.org timed out. (connect timeout=15)')': /simple/pip/
# WARNING: Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ConnectTimeoutError(<pip._vendor.urllib3.connection.HTTPSConnection object at 0x7fbec1a261a0>, 'Connection to pypi.org timed out. (connect timeout=15)')': /simple/pip/
# WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ConnectTimeoutError(<pip._vendor.urllib3.connection.HTTPSConnection object at 0x7f651e469870>, 'Connection to pypi.org timed out. (connect timeout=15)')': /simple/wrapt/
# WARNING: Retrying (Retry(total=3, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ConnectTimeoutError(<pip._vendor.urllib3.connection.HTTPSConnection object at 0x7f651e4699f0>, 'Connection to pypi.org timed out. (connect timeout=15)')': /simple/wrapt/
# WARNING: Retrying (Retry(total=2, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ConnectTimeoutError(<pip._vendor.urllib3.connection.HTTPSConnection object at 0x7f651e469f60>, 'Connection to pypi.org timed out. (connect timeout=15)')': /simple/wrapt/
# WARNING: Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ConnectTimeoutError(<pip._vendor.urllib3.connection.HTTPSConnection object at 0x7f651e46a0e0>, 'Connection to pypi.org timed out. (connect timeout=15)')': /simple/wrapt/
# WARNING: Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ConnectTimeoutError(<pip._vendor.urllib3.connection.HTTPSConnection object at 0x7f651e46a260>, 'Connection to pypi.org timed out. (connect timeout=15)')': /simple/wrapt/

# %% [markdown]
# ### _Ignore any warning or error message ^^ above ^^.  This is OK!_

# %% [markdown]
# # AWS CLI and AWS Python SDK (boto3)

# %%
# !pip install --disable-pip-version-check -q awscli==1.18.216 boto3==1.16.56 botocore==1.19.56
# Out:
# WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ConnectTimeoutError(<pip._vendor.urllib3.connection.HTTPSConnection object at 0x7f2ad35850f0>, 'Connection to pypi.org timed out. (connect timeout=15)')': /simple/awscli/
# WARNING: Retrying (Retry(total=3, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ConnectTimeoutError(<pip._vendor.urllib3.connection.HTTPSConnection object at 0x7f2ad3585240>, 'Connection to pypi.org timed out. (connect timeout=15)')': /simple/awscli/
# WARNING: Retrying (Retry(total=2, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ConnectTimeoutError(<pip._vendor.urllib3.connection.HTTPSConnection object at 0x7f2ad35862f0>, 'Connection to pypi.org timed out. (connect timeout=15)')': /simple/awscli/
# WARNING: Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ConnectTimeoutError(<pip._vendor.urllib3.connection.HTTPSConnection object at 0x7f2ad3586470>, 'Connection to pypi.org timed out. (connect timeout=15)')': /simple/awscli/
# WARNING: Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ConnectTimeoutError(<pip._vendor.urllib3.connection.HTTPSConnection object at 0x7f2ad35865f0>, 'Connection to pypi.org timed out. (connect timeout=15)')': /simple/awscli/
# ERROR: Could not find a version that satisfies the requirement awscli==1.18.216 (from versions: none)
# ERROR: No matching distribution found for awscli==1.18.216

# %% [markdown]
# ### _Ignore any warning or error message ^^ above ^^.  This is OK!_

# %% [markdown]
# # SageMaker

# %%
# !pip install --disable-pip-version-check -q sagemaker==2.29.0
# !pip install --disable-pip-version-check -q smdebug==1.0.1
# !pip install --disable-pip-version-check -q sagemaker-experiments==0.1.26
# Out:
# WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ConnectTimeoutError(<pip._vendor.urllib3.connection.HTTPSConnection object at 0x7f8315c9d8a0>, 'Connection to pypi.org timed out. (connect timeout=15)')': /simple/sagemaker/
# WARNING: Retrying (Retry(total=3, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ConnectTimeoutError(<pip._vendor.urllib3.connection.HTTPSConnection object at 0x7f8315c9db70>, 'Connection to pypi.org timed out. (connect timeout=15)')': /simple/sagemaker/
# WARNING: Retrying (Retry(total=2, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ConnectTimeoutError(<pip._vendor.urllib3.connection.HTTPSConnection object at 0x7f8315c9dde0>, 'Connection to pypi.org timed out. (connect timeout=15)')': /simple/sagemaker/
# WARNING: Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ConnectTimeoutError(<pip._vendor.urllib3.connection.HTTPSConnection object at 0x7f8315c9ded0>, 'Connection to pypi.org timed out. (connect timeout=15)')': /simple/sagemaker/
# WARNING: Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ConnectTimeoutError(<pip._vendor.urllib3.connection.HTTPSConnection object at 0x7f8315c9e050>, 'Connection to pypi.org timed out. (connect timeout=15)')': /simple/sagemaker/
# ERROR: Could not find a version that satisfies the requirement sagemaker==2.29.0 (from versions: none)
# ERROR: No matching distribution found for sagemaker==2.29.0
# WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ConnectTimeoutError(<pip._vendor.urllib3.connection.HTTPSConnection object at 0x7f1ba9c918a0>, 'Connection to pypi.org timed out. (connect timeout=15)')': /simple/smdebug/
# WARNING: Retrying (Retry(total=3, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ConnectTimeoutError(<pip._vendor.urllib3.connection.HTTPSConnection object at 0x7f1ba9c91b70>, 'Connection to pypi.org timed out. (connect timeout=15)')': /simple/smdebug/
# WARNING: Retrying (Retry(total=2, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ConnectTimeoutError(<pip._vendor.urllib3.connection.HTTPSConnection object at 0x7f1ba9c91de0>, 'Connection to pypi.org timed out. (connect timeout=15)')': /simple/smdebug/
# WARNING: Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ConnectTimeoutError(<pip._vendor.urllib3.connection.HTTPSConnection object at 0x7f1ba9c91ed0>, 'Connection to pypi.org timed out. (connect timeout=15)')': /simple/smdebug/
# WARNING: Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ConnectTimeoutError(<pip._vendor.urllib3.connection.HTTPSConnection object at 0x7f1ba9c92050>, 'Connection to pypi.org timed out. (connect timeout=15)')': /simple/smdebug/
# ERROR: Could not find a version that satisfies the requirement smdebug==1.0.1 (from versions: none)
# ERROR: No matching distribution found for smdebug==1.0.1
# WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ConnectTimeoutError(<pip._vendor.urllib3.connection.HTTPSConnection object at 0x7fbc0f555960>, 'Connection to pypi.org timed out. (connect timeout=15)')': /simple/sagemaker-experiments/
# WARNING: Retrying (Retry(total=3, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ConnectTimeoutError(<pip._vendor.urllib3.connection.HTTPSConnection object at 0x7fbc0f555c30>, 'Connection to pypi.org timed out. (connect timeout=15)')': /simple/sagemaker-experiments/
# WARNING: Retrying (Retry(total=2, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ConnectTimeoutError(<pip._vendor.urllib3.connection.HTTPSConnection object at 0x7fbc0f555ea0>, 'Connection to pypi.org timed out. (connect timeout=15)')': /simple/sagemaker-experiments/
# WARNING: Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ConnectTimeoutError(<pip._vendor.urllib3.connection.HTTPSConnection object at 0x7fbc0f555f90>, 'Connection to pypi.org timed out. (connect timeout=15)')': /simple/sagemaker-experiments/
# WARNING: Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ConnectTimeoutError(<pip._vendor.urllib3.connection.HTTPSConnection object at 0x7fbc0f556110>, 'Connection to pypi.org timed out. (connect timeout=15)')': /simple/sagemaker-experiments/
# ERROR: Could not find a version that satisfies the requirement sagemaker-experiments==0.1.26 (from versions: none)
# ERROR: No matching distribution found for sagemaker-experiments==0.1.26

# %% [markdown]
# ### _Ignore any warning or error message ^^ above ^^.  This is OK!_

# %% [markdown]
# # PyAthena

# %%
# !pip install --disable-pip-version-check -q PyAthena==2.1.0
# Out:
# WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ConnectTimeoutError(<pip._vendor.urllib3.connection.HTTPSConnection object at 0x7f61bf8018d0>, 'Connection to pypi.org timed out. (connect timeout=15)')': /simple/pyathena/
# WARNING: Retrying (Retry(total=3, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ConnectTimeoutError(<pip._vendor.urllib3.connection.HTTPSConnection object at 0x7f61bf801ba0>, 'Connection to pypi.org timed out. (connect timeout=15)')': /simple/pyathena/
# WARNING: Retrying (Retry(total=2, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ConnectTimeoutError(<pip._vendor.urllib3.connection.HTTPSConnection object at 0x7f61bf801e10>, 'Connection to pypi.org timed out. (connect timeout=15)')': /simple/pyathena/
# WARNING: Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ConnectTimeoutError(<pip._vendor.urllib3.connection.HTTPSConnection object at 0x7f61bf801f00>, 'Connection to pypi.org timed out. (connect timeout=15)')': /simple/pyathena/
# WARNING: Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ConnectTimeoutError(<pip._vendor.urllib3.connection.HTTPSConnection object at 0x7f61bf802080>, 'Connection to pypi.org timed out. (connect timeout=15)')': /simple/pyathena/
# ERROR: Could not find a version that satisfies the requirement PyAthena==2.1.0 (from versions: none)
# ERROR: No matching distribution found for PyAthena==2.1.0

# %% [markdown]
# ### _Ignore any warning or error message ^^ above ^^.  This is OK!_

# %% [markdown]
# # AWS Data Wrangler

# %%
# !pip install --disable-pip-version-check -q awswrangler==2.13.0
# Out:
# WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ConnectTimeoutError(<pip._vendor.urllib3.connection.HTTPSConnection object at 0x7f6558c198d0>, 'Connection to pypi.org timed out. (connect timeout=15)')': /simple/awswrangler/
# WARNING: Retrying (Retry(total=3, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ConnectTimeoutError(<pip._vendor.urllib3.connection.HTTPSConnection object at 0x7f6558c19ba0>, 'Connection to pypi.org timed out. (connect timeout=15)')': /simple/awswrangler/
# WARNING: Retrying (Retry(total=2, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ConnectTimeoutError(<pip._vendor.urllib3.connection.HTTPSConnection object at 0x7f6558c19e10>, 'Connection to pypi.org timed out. (connect timeout=15)')': /simple/awswrangler/
# WARNING: Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ConnectTimeoutError(<pip._vendor.urllib3.connection.HTTPSConnection object at 0x7f6558c19f00>, 'Connection to pypi.org timed out. (connect timeout=15)')': /simple/awswrangler/
# WARNING: Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ConnectTimeoutError(<pip._vendor.urllib3.connection.HTTPSConnection object at 0x7f6558c1a080>, 'Connection to pypi.org timed out. (connect timeout=15)')': /simple/awswrangler/
# ERROR: Could not find a version that satisfies the requirement awswrangler==2.13.0 (from versions: none)
# ERROR: No matching distribution found for awswrangler==2.13.0

# %% [markdown]
# ### _Ignore any warning or error message ^^ above ^^.  This is OK!_

# %% [markdown]
# # Zip

# %%
# !conda install -y zip
# Out:
# Channels:
#  - defaults
# Platform: linux-64
# Collecting package metadata (repodata.json): / Retrying (Retry(total=2, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7fa31f9fab90>, 'Connection to repo.anaconda.com timed out. (connect timeout=9.15)')': /pkgs/r/linux-64/repodata.json
#
# Retrying (Retry(total=2, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7fa31f9f8fd0>, 'Connection to repo.anaconda.com timed out. (connect timeout=9.15)')': /pkgs/main/linux-64/repodata.json
#
# Retrying (Retry(total=2, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7fa31f9fa1d0>, 'Connection to repo.anaconda.com timed out. (connect timeout=9.15)')': /pkgs/main/noarch/repodata.json
#
# Retrying (Retry(total=2, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7fa31f9fb400>, 'Connection to repo.anaconda.com timed out. (connect timeout=9.15)')': /pkgs/r/noarch/repodata.json
#
# \ Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7fa31f9fb880>, 'Connection to repo.anaconda.com timed out. (connect timeout=9.15)')': /pkgs/main/linux-64/repodata.json
#
# Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7fa31f9fb670>, 'Connection to repo.anaconda.com timed out. (connect timeout=9.15)')': /pkgs/r/linux-64/repodata.json
#
# Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7fa31f9fb9a0>, 'Connection to repo.anaconda.com timed out. (connect timeout=9.15)')': /pkgs/main/noarch/repodata.json
#
# Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7fa31f9fbb80>, 'Connection to repo.anaconda.com timed out. (connect timeout=9.15)')': /pkgs/r/noarch/repodata.json
#
# - Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7fa31f9fbdc0>, 'Connection to repo.anaconda.com timed out. (connect timeout=9.15)')': /pkgs/main/linux-64/repodata.json
#
# Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7fa31f9fbfa0>, 'Connection to repo.anaconda.com timed out. (connect timeout=9.15)')': /pkgs/r/linux-64/repodata.json
#
# Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7fa3278ac100>, 'Connection to repo.anaconda.com timed out. (connect timeout=9.15)')': /pkgs/main/noarch/repodata.json
#
# Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7fa3278ac280>, 'Connection to repo.anaconda.com timed out. (connect timeout=9.15)')': /pkgs/r/noarch/repodata.json
#
# failed
#
# CondaHTTPError: HTTP 000 CONNECTION FAILED for url <https://repo.anaconda.com/pkgs/main/linux-64/repodata.json>
# Elapsed: -
#
# An HTTP error occurred when trying to retrieve this URL.
# HTTP errors are often intermittent, and a simple retry will get you on your way.
#
# If your current network has https://repo.anaconda.com blocked, please file
# a support request with your network engineering team.
#
# 'https//repo.anaconda.com/pkgs/main/linux-64'

# %% [markdown]
# # Matplotlib

# %%
# !pip install --disable-pip-version-check -q matplotlib==3.1.3
# Out:
# WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ConnectTimeoutError(<pip._vendor.urllib3.connection.HTTPSConnection object at 0x7f34e73e98a0>, 'Connection to pypi.org timed out. (connect timeout=15)')': /simple/matplotlib/
# WARNING: Retrying (Retry(total=3, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ConnectTimeoutError(<pip._vendor.urllib3.connection.HTTPSConnection object at 0x7f34e73e9b70>, 'Connection to pypi.org timed out. (connect timeout=15)')': /simple/matplotlib/
# WARNING: Retrying (Retry(total=2, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ConnectTimeoutError(<pip._vendor.urllib3.connection.HTTPSConnection object at 0x7f34e73e9de0>, 'Connection to pypi.org timed out. (connect timeout=15)')': /simple/matplotlib/
# WARNING: Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ConnectTimeoutError(<pip._vendor.urllib3.connection.HTTPSConnection object at 0x7f34e73e9ed0>, 'Connection to pypi.org timed out. (connect timeout=15)')': /simple/matplotlib/
# WARNING: Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ConnectTimeoutError(<pip._vendor.urllib3.connection.HTTPSConnection object at 0x7f34e73ea050>, 'Connection to pypi.org timed out. (connect timeout=15)')': /simple/matplotlib/
# ERROR: Could not find a version that satisfies the requirement matplotlib==3.1.3 (from versions: none)
# ERROR: No matching distribution found for matplotlib==3.1.3

# %% [markdown]
# ### _Ignore any warning or error message ^^ above ^^.  This is OK!_

# %% [markdown]
# # Seaborn

# %%
# !pip install --disable-pip-version-check -q seaborn==0.10.0
# Out:
# WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ConnectTimeoutError(<pip._vendor.urllib3.connection.HTTPSConnection object at 0x7fd398dbd930>, 'Connection to pypi.org timed out. (connect timeout=15)')': /simple/seaborn/
# WARNING: Retrying (Retry(total=3, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ConnectTimeoutError(<pip._vendor.urllib3.connection.HTTPSConnection object at 0x7fd398dbdc00>, 'Connection to pypi.org timed out. (connect timeout=15)')': /simple/seaborn/
# WARNING: Retrying (Retry(total=2, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ConnectTimeoutError(<pip._vendor.urllib3.connection.HTTPSConnection object at 0x7fd398dbde70>, 'Connection to pypi.org timed out. (connect timeout=15)')': /simple/seaborn/
# WARNING: Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ConnectTimeoutError(<pip._vendor.urllib3.connection.HTTPSConnection object at 0x7fd398dbdf60>, 'Connection to pypi.org timed out. (connect timeout=15)')': /simple/seaborn/
# WARNING: Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ConnectTimeoutError(<pip._vendor.urllib3.connection.HTTPSConnection object at 0x7fd398dbe0e0>, 'Connection to pypi.org timed out. (connect timeout=15)')': /simple/seaborn/
# ERROR: Could not find a version that satisfies the requirement seaborn==0.10.0 (from versions: none)
# ERROR: No matching distribution found for seaborn==0.10.0

# %% [markdown]
# ### _Ignore any warning or error message ^^ above ^^.  This is OK!_

# %% [markdown]
# # Summarize

# %%
# !python --version
# Out:
# Python 3.10.13

# %%
# !pip list
# Out:
# Package                               Version
# ------------------------------------- ----------------
# absl-py                               2.0.0
# accelerate                            0.21.0
# aiobotocore                           2.7.0
# aiohttp                               3.8.6
# aioitertools                          0.11.0
# aiosignal                             1.3.1
# aiosqlite                             0.19.0
# altair                                5.1.2
# amazon-codewhisperer-jupyterlab-ext   2.0.1
# amazon-sagemaker-jupyter-scheduler    3.0.4
# ansi2html                             0.0.0
# ansiwrap                              0.8.4
# antlr4-python3-runtime                4.9.3
# anyio                                 3.7.1
# appdirs                               1.4.4
# archspec                              0.2.2
# argon2-cffi                           23.1.0
# argon2-cffi-bindings                  21.2.0
# arrow                                 1.3.0
# astroid                               3.0.1
# asttokens                             2.4.1
# astunparse                            1.6.3
# async-lru                             2.0.4
# async-timeout                         4.0.3
# attrs                                 23.1.0
# autogluon                             0.8.2
# autogluon.common                      0.8.2
# autogluon.core                        0.8.2
# autogluon.features                    0.8.2
# autogluon.multimodal                  0.8.2
# autogluon.tabular                     0.8.2
# autogluon.timeseries                  0.8.2
# autopep8                              2.0.4
# autovizwidget                         0.21.0
# aws-embedded-metrics                  3.2.0
# aws-glue-sessions                     1.0.2
# Babel                                 2.13.1
# backports.functools-lru-cache         1.6.5
# beautifulsoup4                        4.12.2
# binaryornot                           0.4.4
# black                                 23.10.1
# bleach                                6.1.0
# blinker                               1.7.0
# blis                                  0.7.10
# boltons                               23.0.0
# boto3                                 1.28.64
# botocore                              1.31.64
# Brotli                                1.0.9
# cached-property                       1.5.2
# cachetools                            5.3.2
# catalogue                             2.0.10
# catboost                              1.2.2
# certifi                               2023.7.22
# cffi                                  1.16.0
# chardet                               5.2.0
# charset-normalizer                    3.3.2
# click                                 8.1.7
# cloudpathlib                          0.16.0
# cloudpickle                           2.2.1
# colorama                              0.4.6
# comm                                  0.1.4
# conda                                 23.10.0
# conda-libmamba-solver                 23.11.0
# conda-package-handling                2.2.0
# conda_package_streaming               0.9.0
# confection                            0.1.3
# contextlib2                           21.6.0
# contourpy                             1.2.0
# cookiecutter                          2.4.0
# croniter                              1.4.1
# cryptography                          41.0.5
# cycler                                0.12.1
# cymem                                 2.0.8
# cytoolz                               0.12.2
# dash                                  2.14.1
# dask                                  2023.10.1
# dataclasses                           0.8
# dataclasses-json                      0.5.7
# datasets                              2.14.6
# debugpy                               1.8.0
# decorator                             5.1.1
# deepmerge                             1.1.0
# defusedxml                            0.7.1
# dill                                  0.3.7
# distributed                           2023.10.1
# docker-pycreds                        0.4.0
# docstring-to-markdown                 0.13
# entrypoints                           0.4
# et-xmlfile                            1.1.0
# evaluate                              0.4.1
# exceptiongroup                        1.1.3
# executing                             2.0.1
# faiss                                 1.7.4
# fastai                                2.7.13
# fastcore                              1.5.29
# fastdownload                          0.0.7
# fastjsonschema                        2.18.1
# fastprogress                          1.0.3
# filelock                              3.13.1
# flake8                                6.1.0
# Flask                                 3.0.0
# flatbuffers                           23.5.26
# fonttools                             4.44.0
# fqdn                                  1.5.1
# frozenlist                            1.4.0
# fsspec                                2023.6.0
# future                                0.18.3
# gast                                  0.4.0
# gdown                                 4.7.1
# gitdb                                 4.0.11
# GitPython                             3.1.40
# gluonts                               0.13.7
# gmpy2                                 2.1.2
# google-api-core                       2.13.0
# google-auth                           2.23.4
# google-auth-oauthlib                  1.0.0
# google-pasta                          0.2.0
# googleapis-common-protos              1.61.0
# graphviz                              0.20.1
# greenlet                              3.0.1
# grpcio                                1.54.3
# gssapi                                1.8.3
# h5py                                  3.10.0
# hdijupyterutils                       0.21.0
# huggingface-hub                       0.19.0
# idna                                  3.4
# imagecodecs                           2023.8.12
# imageio                               2.31.5
# importlib-metadata                    6.8.0
# importlib-resources                   6.1.1
# ipykernel                             6.26.0
# ipython                               8.17.2
# ipywidgets                            8.1.1
# isoduration                           20.11.0
# isort                                 5.12.0
# itsdangerous                          2.1.2
# jax                                   0.4.19
# jaxlib                                0.4.14
# jedi                                  0.19.1
# Jinja2                                3.1.2
# jmespath                              1.0.1
# joblib                                1.3.2
# json5                                 0.9.14
# jsonpatch                             1.33
# jsonpath-ng                           1.6.0
# jsonpointer                           2.4
# jsonschema                            4.17.3
# jupyter                               1.0.0
# jupyter_ai                            2.5.0
# jupyter_ai_magics                     2.5.0
# jupyter_client                        8.6.0
# jupyter-console                       6.6.3
# jupyter_core                          5.5.0
# jupyter-dash                          0.4.2
# jupyter-events                        0.6.3
# jupyter-lsp                           2.2.0
# jupyter_scheduler                     2.3.0
# jupyter_server                        2.10.0
# jupyter_server_proxy                  4.1.0
# jupyter_server_terminals              0.4.4
# jupyterlab                            4.0.8
# jupyterlab-pygments                   0.2.2
# jupyterlab_server                     2.24.0
# jupyterlab-widgets                    3.0.9
# keras                                 2.12.0
# Keras-Preprocessing                   1.1.2
# kiwisolver                            1.4.5
# krb5                                  0.5.1
# langchain                             0.0.318
# langcodes                             3.3.0
# langsmith                             0.0.60
# libmambapy                            1.5.3
# lightgbm                              3.3.5
# lightning-utilities                   0.9.0
# llvmlite                              0.41.1
# locket                                1.0.0
# Markdown                              3.5.1
# markdown-it-py                        3.0.0
# MarkupSafe                            2.1.3
# marshmallow                           3.20.1
# marshmallow-enum                      1.5.1
# matplotlib                            3.8.1
# matplotlib-inline                     0.1.6
# mccabe                                0.7.0
# mdurl                                 0.1.0
# mistune                               3.0.2
# ml-dtypes                             0.3.1
# mlforecast                            0.7.3
# mock                                  5.1.0
# model-index                           0.1.11
# mpmath                                1.3.0
# msgpack                               1.0.6
# multidict                             6.0.4
# multiprocess                          0.70.15
# munkres                               1.1.4
# murmurhash                            1.0.10
# mypy-extensions                       1.0.0
# nbclient                              0.8.0
# nbconvert                             7.11.0
# nbformat                              5.9.2
# nest-asyncio                          1.5.8
# networkx                              3.2.1
# nlpaug                                1.1.11
# nltk                                  3.8.1
# nose                                  1.3.7
# notebook                              7.0.6
# notebook_shim                         0.2.3
# nptyping                              2.4.1
# numba                                 0.58.1
# numexpr                               2.8.7
# numpy                                 1.26.0
# oauthlib                              3.2.2
# omegaconf                             2.2.3
# openai                                0.28.1
# openapi-schema-pydantic               1.2.4
# openmim                               0.3.7
# openpyxl                              3.1.2
# opt-einsum                            3.3.0
# ordered-set                           4.1.0
# overrides                             7.4.0
# packaging                             23.2
# pandas                                2.1.2
# pandas-stubs                          2.1.1.230928
# pandocfilters                         1.5.0
# papermill                             2.4.0
# parso                                 0.8.3
# partd                                 1.4.1
# pathos                                0.3.1
# pathspec                              0.11.2
# pathtools                             0.1.2
# pathy                                 0.10.2
# patsy                                 0.5.3
# pexpect                               4.8.0
# pickleshare                           0.7.5
# Pillow                                9.5.0
# pip                                   23.3.1
# pkgutil_resolve_name                  1.3.10
# platformdirs                          3.5.1
# plotly                                5.18.0
# pluggy                                1.3.0
# ply                                   3.11
# pox                                   0.3.3
# ppft                                  1.7.6.7
# preshed                               3.0.9
# prometheus-client                     0.18.0
# prompt-toolkit                        3.0.39
# protobuf                              4.21.12
# psutil                                5.9.5
# ptyprocess                            0.7.0
# pure-eval                             0.2.2
# pure-sasl                             0.6.2
# pyarrow                               12.0.1
# pyasn1                                0.5.0
# pyasn1-modules                        0.3.0
# pycodestyle                           2.11.1
# pycosat                               0.6.6
# pycparser                             2.21
# pydantic                              1.10.13
# pydocstyle                            6.3.0
# pyflakes                              3.1.0
# Pygments                              2.16.1
# PyHive                                0.7.0
# PyJWT                                 2.8.0
# pylint                                3.0.2
# pyOpenSSL                             23.3.0
# pyparsing                             3.1.1
# PyQt5                                 5.15.9
# PyQt5-sip                             12.12.2
# pyrsistent                            0.20.0
# PySocks                               1.7.1
# pyspnego                              0.9.1
# pytesseract                           0.3.10
# python-dateutil                       2.8.2
# python-json-logger                    2.0.7
# python-lsp-jsonrpc                    1.1.2
# python-lsp-server                     1.9.0
# python-slugify                        8.0.1
# pytoolconfig                          1.2.5
# pytorch-lightning                     2.0.9
# pytorch-metric-learning               1.7.3
# pytz                                  2023.3
# pyu2f                                 0.1.5
# PyWavelets                            1.4.1
# PyYAML                                6.0.1
# pyzmq                                 25.1.1
# qtconsole                             5.5.0
# QtPy                                  2.4.1
# regex                                 2023.10.3
# requests                              2.31.0
# requests-kerberos                     0.14.0
# requests-oauthlib                     1.3.1
# responses                             0.18.0
# retrying                              1.3.3
# rfc3339-validator                     0.1.4
# rfc3986-validator                     0.1.1
# rich                                  13.6.0
# rope                                  1.11.0
# rsa                                   4.9
# ruamel.yaml                           0.18.5
# ruamel.yaml.clib                      0.2.7
# s3transfer                            0.7.0
# sacremoses                            0.0.53
# safetensors                           0.3.3
# sagemaker                             2.197.0
# sagemaker-headless-execution-driver   0.0.9
# sagemaker-jupyterlab-emr-extension    0.1.9
# sagemaker-jupyterlab-extension        0.1.9
# sagemaker-jupyterlab-extension-common 0.1.9
# sagemaker-kernel-wrapper              0.0.2
# sagemaker-studio-analytics-extension  0.0.21
# sagemaker-studio-sparkmagic-lib       0.1.4
# sasl                                  0.3.1
# schema                                0.7.5
# scikit-image                          0.19.3
# scikit-learn                          1.3.2
# scipy                                 1.11.3
# Send2Trash                            1.8.2
# sentencepiece                         0.1.99
# sentry-sdk                            1.34.0
# seqeval                               1.2.2
# setproctitle                          1.3.3
# setuptools                            68.2.2
# shellingham                           1.5.4
# simpervisor                           1.0.0
# sip                                   6.7.12
# six                                   1.16.0
# smart-open                            5.2.1
# smdebug-rulesconfig                   1.0.1
# smmap                                 5.0.0
# sniffio                               1.3.0
# snowballstemmer                       2.2.0
# sortedcontainers                      2.4.0
# soupsieve                             2.5
# spacy                                 3.7.2
# spacy-legacy                          3.0.12
# spacy-loggers                         1.0.5
# sparkmagic                            0.21.0
# SQLAlchemy                            1.4.49
# srsly                                 2.4.8
# stack-data                            0.6.2
# statsforecast                         1.4.0
# statsmodels                           0.14.0
# stringcase                            1.2.0
# supervisor                            4.2.5
# sympy                                 1.12
# tabulate                              0.9.0
# tblib                                 1.7.0
# tenacity                              8.2.3
# tensorboard                           2.12.3
# tensorboard-data-server               0.7.0
# tensorflow                            2.12.1
# tensorflow-estimator                  2.12.0
# termcolor                             2.3.0
# terminado                             0.17.1
# text-unidecode                        1.3
# textwrap3                             0.9.2
# thinc                                 8.2.1
# threadpoolctl                         3.2.0
# thrift                                0.19.0
# thrift-sasl                           0.4.3
# tifffile                              2023.9.26
# tiktoken                              0.5.1
# timm                                  0.9.10
# tinycss2                              1.2.1
# tokenizers                            0.13.3
# toml                                  0.10.2
# tomli                                 2.0.1
# tomlkit                               0.12.2
# toolz                                 0.12.0
# torch                                 2.0.0.post101
# torchmetrics                          1.0.3
# torchvision                           0.15.2a0+072ec57
# tornado                               6.3.3
# tqdm                                  4.66.1
# traitlets                             5.13.0
# transformers                          4.31.0
# truststore                            0.8.0
# typer                                 0.9.0
# types-python-dateutil                 2.8.19.14
# types-pytz                            2023.3.1.1
# typing_extensions                     4.5.0
# typing-inspect                        0.9.0
# typing-utils                          0.1.0
# typish                                1.9.3
# tzdata                                2023.3
# ujson                                 5.8.0
# unicodedata2                          15.1.0
# uri-template                          1.3.0
# urllib3                               1.26.18
# wandb                                 0.15.12
# wasabi                                1.1.2
# wcwidth                               0.2.9
# weasel                                0.3.4
# webcolors                             1.13
# webencodings                          0.5.1
# websocket-client                      1.6.4
# Werkzeug                              3.0.1
# whatthepatch                          1.0.5
# wheel                                 0.41.3
# widgetsnbextension                    4.0.9
# window-ops                            0.0.14
# wrapt                                 1.15.0
# xgboost                               1.7.6
# xxhash                                3.4.1
# yapf                                  0.40.1
# yarl                                  1.9.2
# zict                                  3.0.0
# zipp                                  3.17.0
# zstandard                             0.22.0

# %%
setup_dependencies_passed = True

# %%
# %store setup_dependencies_passed
# Out:
# Stored 'setup_dependencies_passed' (bool)

# %%
# %store
# Out:
# Stored variables and their in-db values:
# setup_dependencies_passed             -> True

# %% [markdown]
# # Release Resources

# %%
# %%html
#
# <p><b>Shutting down your kernel for this notebook to release resources.</b></p>
# <button class="sm-command-button" data-commandlinker-command="kernelmenu:shutdown" style="display:none;">Shutdown Kernel</button>
#
# <script>
# try {
#     els = document.getElementsByClassName("sm-command-button");
#     els[0].click();
# }
# catch(err) {
#     // NoOp
# }
# </script>
# Out:
# <p><b>Shutting down your kernel for this notebook to release resources.</b></p>
# <button class="sm-command-button" data-commandlinker-command="kernelmenu:shutdown" style="display:none;">Shutdown Kernel</button>
#
# <script>
# try {
#     els = document.getElementsByClassName("sm-command-button");
#     els[0].click();
# }
# catch(err) {
#     // NoOp
# }
# </script>

# %%
# %%javascript
#
# try {
#     Jupyter.notebook.save_checkpoint();
#     Jupyter.notebook.session.delete();
# }
# catch(err) {
#     // NoOp
# }
